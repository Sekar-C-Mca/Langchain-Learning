# %%
import os
from   dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")

# %%
import sys
# !{sys.executable} -m pip install -U langchain-openai
from langchain_openai import OpenAIEmbeddings

embedding = OpenAIEmbeddings(
    model="text-embedding-3-large"
)

print(embedding)
# Out:
# Collecting langchain-openai
#   Using cached langchain_openai-1.2.1-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.3.2 in ./venve/lib/python3.10/site-packages (from langchain-openai) (1.3.3)
# Collecting openai<3.0.0,>=2.26.0 (from langchain-openai)
#   Using cached openai-2.36.0-py3-none-any.whl.metadata (31 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.12.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./venve/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.10 in ./venve/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in ./venve/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.8.3)
# Requirement already satisfied: packaging>=23.2.0 in ./venve/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (26.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./venve/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in ./venve/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./venve/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./venve/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in ./venve/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in ./venve/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./venve/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in ./venve/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./venve/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in ./venve/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (2.33.1)
# Requirement already satisfied: xxhash>=3.0.0 in ./venve/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in ./venve/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.25.0)
# Requirement already satisfied: anyio in ./venve/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (4.13.0)
# Requirement already satisfied: certifi in ./venve/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in ./venve/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in ./venve/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.13)
# Requirement already satisfied: h11>=0.16 in ./venve/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.16.0)
# Collecting distro<2,>=1.7.0 (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Downloading jiter-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Collecting sniffio (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./venve/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venve/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in ./venve/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.2->langchain-openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venve/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.2->langchain-openai) (0.4.2)
# Collecting regex>=2022.1.18 (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading regex-2026.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venve/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in ./venve/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-openai) (2.7.0)
# Using cached langchain_openai-1.2.1-py3-none-any.whl (98 kB)
# Using cached openai-2.36.0-py3-none-any.whl (1.3 MB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (358 kB)
# Downloading tiktoken-0.12.0-cp310-cp310-manylinux_2_28_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.0 MB/s  0:00:00
# Downloading regex-2026.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (793 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.6/793.6 kB 30.1 MB/s  0:00:00
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: tqdm, sniffio, regex, jiter, distro, tiktoken, openai, langchain-openai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [langchain-openai][langchain-openai]
# Successfully installed distro-1.9.0 jiter-0.14.0 langchain-openai-1.2.1 openai-2.36.0 regex-2026.4.4 sniffio-1.3.1 tiktoken-0.12.0 tqdm-4.67.3
# client=<openai.resources.embeddings.Embeddings object at 0x756841122e60> async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x756840edf070> model='text-embedding-3-large' dimensions=None deployment='text-embedding-ada-002' openai_api_version=None openai_api_base=None openai_api_type=None openai_proxy=None embedding_ctx_length=8191 openai_api_key=SecretStr('**********') openai_organization=None allowed_special=None disallowed_special=None chunk_size=1000 max_retries=2 request_timeout=None headers=None tiktoken_enabled=True tiktoken_model_name=None show_progress_bar=False model_kwargs={} skip_empty=False default_headers=None default_query=None retry_min_seconds=4 retry_max_seconds=20 http_client=None http_async_client=None check_embedding_ctx_length=True

# %%
text="Hi how are you doing today?"
new=embedding.embed_query(text)
new
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 text="Hi how are you doing today?"
# ----> 2 new=embedding.embed_query(text)
#       3 new
#
# File /workspaces/Langchain-Learning/venve/lib/python3.10/site-packages/langchain_openai/embeddings/base.py:801, in OpenAIEmbeddings.embed_query(self, text, **kwargs)
#     791 """Call out to OpenAI's embedding endpoint for embedding query text.
#     792
#     793 Args:
#    (...)
#     798     Embedding for the text.
#     799 """
#     800 self._ensure_sync_client_available()
# --> 801 return self.embed_documents([text], **kwargs)[0]
#
# File /workspaces/Langchain-Learning/venve/lib/python3.10/site-packages/langchain_openai/embeddings/base.py:751, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     748 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     749 # This could be optimized to avoid double work when all texts are short enough.
#     750 engine = cast(str, self.deployment)
# --> 751 return self._get_len_safe_embeddings(
#     752     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     753 )
#
# File /workspaces/Langchain-Learning/venve/lib/python3.10/site-packages/langchain_openai/embeddings/base.py:618, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     616 # Make API call with this batch
#     617 batch_tokens = tokens[i:batch_end]
# --> 618 response = self.client.create(input=batch_tokens, **client_kwargs)
#     619 if not isinstance(response, dict):
#     620     response = response.model_dump()
#
# File /workspaces/Langchain-Learning/venve/lib/python3.10/site-packages/openai/resources/embeddings.py:136, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     130             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     131                 base64.b64decode(data), dtype="float32"
#     132             ).tolist()
#     134     return obj
# --> 136 return self._post(
#     137     "/embeddings",
#     138     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     139     options=make_request_options(
#     140         extra_headers=extra_headers,
#     141         extra_query=extra_query,
#     142         extra_body=extra_body,
#     143         timeout=timeout,
#     144         post_parser=parser,
#     145         security={"bearer_auth": True},
#     146     ),
#     147     cast_to=CreateEmbeddingResponse,
#     148 )
#
# File /workspaces/Langchain-Learning/venve/lib/python3.10/site-packages/openai/_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /workspaces/Langchain-Learning/venve/lib/python3.10/site-packages/openai/_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(
    model="models/gemini-embedding-001"
)

vector = embeddings.embed_query("What is the meaning of life?")

print(len(vector))
print(vector[:5])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from langchain_google_genai import GoogleGenerativeAIEmbeddings
#       3 embeddings = GoogleGenerativeAIEmbeddings(
#       4     model="models/gemini-embedding-001"
#       5 )
#       7 vector = embeddings.embed_query("What is the meaning of life?")
#
# ModuleNotFoundError: No module named 'langchain_google_genai'
